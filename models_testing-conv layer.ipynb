# %%
import pandas as pd
import time
df = pd.read_csv("/Users/divy/Desktop/Divy/Image Clasification(Biswa)/Startly/csvs/random_data_notop.csv")
# df.columns = ['v1', 'v2', 'v3', 'v4', 'material']

# %%
df
# Out:
#                                               file_path  block1_conv1  \
# 0     feature_vectors_notop/Moody_Hip_Coffee/photo-1...             2
# 1     feature_vectors_notop/Moody_Hip_Coffee/pexels-...            -1
# 2     feature_vectors_notop/Moody_Hip_Coffee/photo-1...             0
# 3     feature_vectors_notop/Moody_Hip_Coffee/photo-1...             1
# 4     feature_vectors_notop/Moody_Hip_Coffee/photo-1...             1
# ...                                                 ...           ...
# 1199  feature_vectors_notop/Beige_Soft_Lifestyle/pho...            -1
# 1200  feature_vectors_notop/Beige_Soft_Lifestyle/pho...             0
# 1201  feature_vectors_notop/Beige_Soft_Lifestyle/pho...            -1
# 1202  feature_vectors_notop/Beige_Soft_Lifestyle/pho...            -1
# 1203  feature_vectors_notop/Beige_Soft_Lifestyle/pho...             2
#
#       block2_conv1  block3_conv1  block4_conv1  block5_conv1  block5_pool  \
# 0               -1             1             1            -1            1
# 1               -2             1             4             1            0
# 2                0            -2             0            -1            0
# 3                0             0             0             1            1
# 4               -2            -2             1             0           -1
# ...            ...           ...           ...           ...          ...
# 1199             0             1             2             1            0
# 1200             1             3             0             1           -1
# 1201            -3            -2             0             0            0
# 1202             1             1             0             2           -5
# 1203             1            -2            -1             0            1
#
#       average5  average6
# 0            0         0
# 1            0         0
# 2            0         2
# 3           -1         0
# 4           -1         0
# ...        ...       ...
# 1199        -2         0
# 1200        -3        -3
# 1201         2         0
# 1202         1         0
# 1203         0        -3
#
# [1204 rows x 9 columns]

# %%
import numpy as np
X = np.asarray([np.load(e[0]) for e in df.iloc[:,:1].values])

# %%
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1',
                'block5_pool',
                'average5',
                'average6']

# %%
ys = {}
i=0
while i<len(style_layers):
    ys[style_layers[i]] = {}
    ys[style_layers[i]] = df.iloc[:,i+1].values
    i += 1

# %%
# models = {}

# %%
model = {}
# train_mse = {}
# test_mse = {}
# train_mse = {}

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
model["SGD"] = {}
for s in ys.keys():
    X_train, X_test, y_train, y_test = train_test_split(X, ys[s], test_size = 0.2, random_state = 0)
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    regressor = SGDRegressor()
    start = time.time()
    regressor.fit(X_train, y_train)
    train_time = time.time() - start
    model["SGD"][s] = {}
    start = time.time()
    y_pred = regressor.predict(X_test)
    y_train_pred = regressor.predict(X_train)
    pred_time = time.time() - start
    model["SGD"][s]["time_train"] = train_time
    model["SGD"][s]["pred_train"] = pred_time
    test_mse = mean_squared_error(y_test,y_pred)
    train_mse = mean_squared_error(y_train,y_train_pred)
    model["SGD"][s]["train_mse"] = train_mse
    model["SGD"][s]["test_mse"] = test_mse
    model["SGD"][s]["y_pred"] = y_pred
    model["SGD"][s]["y_train_pred"] = y_train_pred
    model["SGD"][s]["model"] = regressor

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler as ss
model["SVM"] = {}
for s in ys.keys():
    X_train, X_test, y_train, y_test = train_test_split(X, ys[s], test_size = 0.2, random_state = 0)
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    sc = ss()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    regressor = SVR()
    start = time.time()
    regressor.fit(X_train, y_train)
    train_time = time.time() - start
    model["SVM"][s] = {}
    start = time.time()
    y_pred = regressor.predict(X_test)
    y_train_pred = regressor.predict(X_train)
    pred_time = time.time() - start
    model["SVM"][s]["time_train"] = train_time
    model["SVM"][s]["pred_train"] = pred_time
    test_mse = mean_squared_error(y_test,y_pred)
    train_mse = mean_squared_error(y_train,y_train_pred)
    model["SVM"][s]["train_mse"] = train_mse
    model["SVM"][s]["test_mse"] = test_mse
    model["SVM"][s]["y_pred"] = y_pred
    model["SVM"][s]["y_train_pred"] = y_train_pred
    model["SVM"][s]["model"] = regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler as ss
model["DecisionTree"] = {}
for s in ys.keys():
    X_train, X_test, y_train, y_test = train_test_split(X, ys[s], test_size = 0.2, random_state = 0)
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    regressor = DecisionTreeRegressor()
    start = time.time()
    regressor.fit(X_train, y_train)
    train_time = time.time() - start
    model["DecisionTree"][s] = {}
    start = time.time()
    y_pred = regressor.predict(X_test)
    y_train_pred = regressor.predict(X_train)
    pred_time = time.time() - start
    model["DecisionTree"][s]["time_train"] = train_time
    model["DecisionTree"][s]["pred_train"] = pred_time
    test_mse = mean_squared_error(y_test,y_pred)
    train_mse = mean_squared_error(y_train,y_train_pred)
    model["DecisionTree"][s]["train_mse"] = train_mse
    model["DecisionTree"][s]["test_mse"] = test_mse
    model["DecisionTree"][s]["y_pred"] = y_pred
    model["DecisionTree"][s]["y_train_pred"] = y_train_pred
    model["DecisionTree"][s]["model"] = regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler as ss
model["RandomForest"] = {}
for s in ys.keys():
    X_train, X_test, y_train, y_test = train_test_split(X, ys[s], test_size = 0.2, random_state = 0)
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    regressor = RandomForestRegressor()
    start = time.time()
    regressor.fit(X_train, y_train)
    train_time = time.time() - start
    model["RandomForest"][s] = {}
    start = time.time()
    y_pred = regressor.predict(X_test)
    y_train_pred = regressor.predict(X_train)
    pred_time = time.time() - start
    model["RandomForest"][s]["time_train"] = train_time
    model["RandomForest"][s]["pred_train"] = pred_time
    test_mse = mean_squared_error(y_test,y_pred)
    train_mse = mean_squared_error(y_train,y_train_pred)
    model["RandomForest"][s]["train_mse"] = train_mse
    model["RandomForest"][s]["test_mse"] = test_mse
    model["RandomForest"][s]["y_pred"] = y_pred
    model["RandomForest"][s]["y_train_pred"] = y_train_pred
    model["RandomForest"][s]["model"] = regressor

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler as ss
model["XGBoost"] = {}
for s in ys.keys():
    X_train, X_test, y_train, y_test = train_test_split(X, ys[s], test_size = 0.2, random_state = 0)
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    regressor = XGBRegressor()
    start = time.time()
    regressor.fit(X_train, y_train)
    train_time = time.time() - start
    model["XGBoost"][s] = {}
    start = time.time()
    y_pred = regressor.predict(X_test)
    y_train_pred = regressor.predict(X_train)
    pred_time = time.time() - start
    model["XGBoost"][s]["time_train"] = train_time
    model["XGBoost"][s]["pred_train"] = pred_time
    test_mse = mean_squared_error(y_test,y_pred)
    train_mse = mean_squared_error(y_train,y_train_pred)
    model["XGBoost"][s]["train_mse"] = train_mse
    model["XGBoost"][s]["test_mse"] = test_mse
    model["XGBoost"][s]["y_pred"] = y_pred
    model["XGBoost"][s]["y_train_pred"] = y_train_pred
    model["XGBoost"][s]["model"] = regressor

# %%
csv = ["model"]
csv += style_layers
csv = f'{",".join(csv)}\n'
for m in model.keys():
    l = []
    l.append(m)
    for s in model[m].keys():
        l.append(f'{model[m][s]["test_mse"]}')
    csv += f'{",".join(l)}\n'

# %%
print(csv)
# Out:
# model,block1_conv1,block2_conv1,block3_conv1,block4_conv1,block5_conv1,block5_pool,average5,average6
# SGD,3.3263491299066704e+29,2.1792080760968495e+29,3.16724014206602e+29,2.564248293518726e+29,3.353573231521991e+29,3.282731633191057e+29,1.6933588633946203e+29,4.5840912215872996e+29
# SVM,1.651082774853316,2.180481670282951,1.961512706159692,1.959232773610734,2.0067264952603585,1.7441224568168645,1.7259160560356053,1.9195257817225284
# DecisionTree,3.9429460580912865,3.9813278008298756,3.2997925311203318,3.7562240663900415,3.896265560165975,3.900414937759336,3.5228215767634854,3.4107883817427385
# RandomForest,1.6907046524331726,2.2494942227120793,1.9772951092692956,1.9983562963700001,2.0896706077756138,1.907749302864576,1.7358800481788845,1.953395732826187
# XGBoost,2.2565080341580908,2.756290952968467,2.3277725254762114,2.3933811965412284,2.3909014143973155,2.3917003484069808,2.0815899171124816,2.287297203701902

# %%
file = open("/Users/divy/Desktop/Divy/Image Clasification(Biswa)/results_conv.csv", mode="x")
file.write(csv)
file.close()

# %%
model["XGBoost"][s]["time_train"]
# Out:
# 90.56969285011292

# %%
model["RandomForest"][s]["time_train"]
# Out:
# 316.0850238800049

# %%
from sklearn.metrics import accuracy_score
y = [np.argmax(e) for e in df.iloc[:,1:].values]
for m in model.keys():
    X_ = X
    X_ = X_.reshape(X_.shape[0], -1)
    if m == "SVM":
        X_ = sc.transform(X_)
    y_pred = []
    for s in model[m].keys():
        model_ = model[m][s]['model']
        y_pred_ = model_.predict(X_)
        y_pred.append(y_pred_)
    y_pred = np.asarray(y_pred)
    y_pred = y_pred.reshape(y_pred.shape[1],y_pred.shape[0])
    y_pred = [np.argmax(e) for e in y_pred]
    print(f"{m} : {accuracy_score(y, y_pred)*100:.3f}%")
# Out:
# SGD : 12.375%
# SVM : 13.621%
# DecisionTree : 15.116%
# RandomForest : 13.123%
# XGBoost : 14.369%

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler
n_class = 8
# shape = x_train.shape[1] * x_train.shape[2] * x_train.shape[3]
x_train, x_test, y_train, y_test = train_test_split(X.reshape(X.shape[0],-1), df.iloc[:,1:].values, test_size = 0.2, random_state = 0)
# X_train = X_train.reshape(X_train.shape[0], -1)
# X_test = X_test.reshape(X_test.shape[0], -1)
inp = tf.keras.Input(shape=(x_train.shape[1],))
x = layers.Dense(15, activation="relu")(inp)
x = layers.Dropout(0.4)(x)
x = layers.Dense(30, activation="relu")(inp)
x = layers.Dropout(0.4)(x)
x = layers.Dense(60, activation="relu")(inp)
x = layers.Dropout(0.4)(x)
x = layers.Dense(30, activation="relu")(inp)
x = layers.Dropout(0.4)(x)
x = layers.Dense(15, activation="relu")(inp)
x = layers.Dropout(0.4)(x)
output = layers.Dense(n_class, activation="softmax")(x)

model = tf.keras.Model(inp, output)
optimizer = tf.keras.optimizers.RMSprop(lr=1e-3)
model.compile(optimizer, "categorical_crossentropy", metrics=["accuracy"])

# %%
    import math
    epochs, verbose = 100, 1
    initial_learning_rate = 1e-3
#     def lr_exp_decay(epoch, lr):
#         k = 1e-5
#         return initial_learning_rate * math.exp(-k * epoch)

    model.fit(x_train, np.asarray(y_train), 5, epochs,
              verbose=verbose, validation_data=(x_test, np.asarray(y_test)))
# Out:
# Epoch 1/100
# 193/193 [==============================] - 0s 1ms/step - loss: -2.5950 - accuracy: 0.0914 - val_loss: 0.5106 - val_accuracy: 0.1245
# Epoch 2/100
# 193/193 [==============================] - 0s 1ms/step - loss: -16.5457 - accuracy: 0.1163 - val_loss: 0.4043 - val_accuracy: 0.0830
# Epoch 3/100
# 193/193 [==============================] - 0s 1ms/step - loss: -62.8870 - accuracy: 0.1371 - val_loss: 14.0289 - val_accuracy: 0.1369
# Epoch 4/100
# 193/193 [==============================] - 0s 1ms/step - loss: -153.8625 - accuracy: 0.1506 - val_loss: 5.7836 - val_accuracy: 0.1992
# Epoch 5/100
# 193/193 [==============================] - 0s 1ms/step - loss: -310.3751 - accuracy: 0.1630 - val_loss: 20.2082 - val_accuracy: 0.2033
# Epoch 6/100
# 193/193 [==============================] - 0s 1ms/step - loss: -464.2469 - accuracy: 0.1911 - val_loss: 38.6270 - val_accuracy: 0.1535
# Epoch 7/100
# 193/193 [==============================] - 0s 1ms/step - loss: -777.7787 - accuracy: 0.1973 - val_loss: 50.3665 - val_accuracy: 0.1909
# Epoch 8/100
# 193/193 [==============================] - 0s 1ms/step - loss: -928.1810 - accuracy: 0.1796 - val_loss: 56.3654 - val_accuracy: 0.2116
# Epoch 9/100
# 193/193 [==============================] - 0s 2ms/step - loss: -1311.7716 - accuracy: 0.1994 - val_loss: 74.1255 - val_accuracy: 0.2033
# Epoch 10/100
# 193/193 [==============================] - 0s 2ms/step - loss: -1493.0813 - accuracy: 0.1869 - val_loss: 117.0964 - val_accuracy: 0.1826
# Epoch 11/100
# 193/193 [==============================] - 0s 1ms/step - loss: -1981.3961 - accuracy: 0.2160 - val_loss: 161.5951 - val_accuracy: 0.1452
# Epoch 12/100
# 193/193 [==============================] - 0s 1ms/step - loss: -2307.5222 - accuracy: 0.1890 - val_loss: 234.4771 - val_accuracy: 0.1826
# Epoch 13/100
# 193/193 [==============================] - 0s 1ms/step - loss: -2740.2866 - accuracy: 0.2025 - val_loss: 286.0132 - val_accuracy: 0.1992
# Epoch 14/100
# 193/193 [==============================] - 0s 1ms/step - loss: -2578.0481 - accuracy: 0.1786 - val_loss: 288.5511 - val_accuracy: 0.1950
# Epoch 15/100
# 193/193 [==============================] - 0s 1ms/step - loss: -3382.8674 - accuracy: 0.1931 - val_loss: 370.4641 - val_accuracy: 0.1328
# Epoch 16/100
# 193/193 [==============================] - 0s 1ms/step - loss: -3678.3027 - accuracy: 0.1921 - val_loss: 372.4085 - val_accuracy: 0.1701
# Epoch 17/100
# 193/193 [==============================] - 0s 1ms/step - loss: -4200.5806 - accuracy: 0.1973 - val_loss: 411.7689 - val_accuracy: 0.1784
# Epoch 18/100
# 193/193 [==============================] - 0s 1ms/step - loss: -3970.6284 - accuracy: 0.1620 - val_loss: 465.1145 - val_accuracy: 0.1411
# Epoch 19/100
# 193/193 [==============================] - 0s 1ms/step - loss: -4020.8547 - accuracy: 0.1796 - val_loss: 471.0031 - val_accuracy: 0.1660
# Epoch 20/100
# 193/193 [==============================] - 0s 1ms/step - loss: -4489.0654 - accuracy: 0.1630 - val_loss: 502.9889 - val_accuracy: 0.2075
# Epoch 21/100
# 193/193 [==============================] - 0s 1ms/step - loss: -5452.6831 - accuracy: 0.1952 - val_loss: 599.6108 - val_accuracy: 0.1079
# Epoch 22/100
# 193/193 [==============================] - 0s 1ms/step - loss: -5888.9043 - accuracy: 0.1641 - val_loss: 607.3878 - val_accuracy: 0.1203
# Epoch 23/100
# 193/193 [==============================] - 0s 1ms/step - loss: -5385.8345 - accuracy: 0.1900 - val_loss: 719.6101 - val_accuracy: 0.1079
# Epoch 24/100
# 193/193 [==============================] - 0s 1ms/step - loss: -5876.2246 - accuracy: 0.1713 - val_loss: 802.1348 - val_accuracy: 0.0871
# Epoch 25/100
# 193/193 [==============================] - 0s 1ms/step - loss: -6015.6357 - accuracy: 0.1828 - val_loss: 809.5945 - val_accuracy: 0.1037
# Epoch 26/100
# 193/193 [==============================] - 0s 1ms/step - loss: -7187.6899 - accuracy: 0.1848 - val_loss: 849.5101 - val_accuracy: 0.1411
# Epoch 27/100
# 193/193 [==============================] - 0s 1ms/step - loss: -7229.1758 - accuracy: 0.1724 - val_loss: 905.9825 - val_accuracy: 0.0996
# Epoch 28/100
# 193/193 [==============================] - 0s 1ms/step - loss: -7019.5142 - accuracy: 0.1682 - val_loss: 900.1620 - val_accuracy: 0.1411
# Epoch 29/100
# 193/193 [==============================] - 0s 2ms/step - loss: -7576.8491 - accuracy: 0.1620 - val_loss: 991.1369 - val_accuracy: 0.1535
# Epoch 30/100
# 193/193 [==============================] - 0s 1ms/step - loss: -8302.6953 - accuracy: 0.1703 - val_loss: 1096.4967 - val_accuracy: 0.1328
# Epoch 31/100
# 193/193 [==============================] - 0s 1ms/step - loss: -8658.1377 - accuracy: 0.1921 - val_loss: 1166.5953 - val_accuracy: 0.1286
# Epoch 32/100
# 193/193 [==============================] - 0s 1ms/step - loss: -9448.8975 - accuracy: 0.1921 - val_loss: 1273.5027 - val_accuracy: 0.0996
# Epoch 33/100
# 193/193 [==============================] - 0s 1ms/step - loss: -8755.5703 - accuracy: 0.1661 - val_loss: 1328.6426 - val_accuracy: 0.1120
# Epoch 34/100
# 193/193 [==============================] - 0s 1ms/step - loss: -7702.1890 - accuracy: 0.1641 - val_loss: 1425.8794 - val_accuracy: 0.1079
# Epoch 35/100
# 193/193 [==============================] - 0s 1ms/step - loss: -8328.7236 - accuracy: 0.1547 - val_loss: 1469.8639 - val_accuracy: 0.1162
# Epoch 36/100
# 193/193 [==============================] - 0s 1ms/step - loss: -9821.3066 - accuracy: 0.1475 - val_loss: 1706.1637 - val_accuracy: 0.1535
# Epoch 37/100
# 193/193 [==============================] - 0s 1ms/step - loss: -10752.1514 - accuracy: 0.1682 - val_loss: 1691.4083 - val_accuracy: 0.1162
# Epoch 38/100
# 193/193 [==============================] - 0s 1ms/step - loss: -10246.9434 - accuracy: 0.1641 - val_loss: 1793.6813 - val_accuracy: 0.0954
# Epoch 39/100
# 193/193 [==============================] - 0s 1ms/step - loss: -10436.4609 - accuracy: 0.1724 - val_loss: 1903.6003 - val_accuracy: 0.1162
# Epoch 40/100
# 193/193 [==============================] - 0s 1ms/step - loss: -11433.8057 - accuracy: 0.1350 - val_loss: 2286.6204 - val_accuracy: 0.1701
# Epoch 41/100
# 193/193 [==============================] - 0s 2ms/step - loss: -9683.3320 - accuracy: 0.1672 - val_loss: 2343.6829 - val_accuracy: 0.1660
# Epoch 42/100
# 193/193 [==============================] - 0s 1ms/step - loss: -12534.0195 - accuracy: 0.1454 - val_loss: 2320.7878 - val_accuracy: 0.1079
# Epoch 43/100
# 193/193 [==============================] - 0s 1ms/step - loss: -11228.6396 - accuracy: 0.1599 - val_loss: 2123.8914 - val_accuracy: 0.1079
# Epoch 44/100
# 193/193 [==============================] - 0s 1ms/step - loss: -11616.8818 - accuracy: 0.1817 - val_loss: 2102.1130 - val_accuracy: 0.0954
# Epoch 45/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13940.7148 - accuracy: 0.1651 - val_loss: 2360.2837 - val_accuracy: 0.0996
# Epoch 46/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13747.1611 - accuracy: 0.1610 - val_loss: 2419.6260 - val_accuracy: 0.0871
# Epoch 47/100
# 193/193 [==============================] - 0s 1ms/step - loss: -14013.3027 - accuracy: 0.1734 - val_loss: 2689.9136 - val_accuracy: 0.1079
# Epoch 48/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13394.3506 - accuracy: 0.1703 - val_loss: 2681.6418 - val_accuracy: 0.0871
# Epoch 49/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13672.5518 - accuracy: 0.1589 - val_loss: 2838.1799 - val_accuracy: 0.0996
# Epoch 50/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13663.0762 - accuracy: 0.1475 - val_loss: 2664.7400 - val_accuracy: 0.0996
# Epoch 51/100
# 193/193 [==============================] - 0s 1ms/step - loss: -12467.3223 - accuracy: 0.1537 - val_loss: 2805.0913 - val_accuracy: 0.0954
# Epoch 52/100
# 193/193 [==============================] - 0s 1ms/step - loss: -12596.0947 - accuracy: 0.1651 - val_loss: 2478.0486 - val_accuracy: 0.1037
# Epoch 53/100
# 193/193 [==============================] - 0s 1ms/step - loss: -13536.8711 - accuracy: 0.1568 - val_loss: 2895.7217 - val_accuracy: 0.0954
# Epoch 54/100
# 193/193 [==============================] - 0s 1ms/step - loss: -11158.3438 - accuracy: 0.1433 - val_loss: 2801.0320 - val_accuracy: 0.0871
# Epoch 55/100
# 193/193 [==============================] - 0s 1ms/step - loss: -15366.5342 - accuracy: 0.1620 - val_loss: 2940.0110 - val_accuracy: 0.1120
# Epoch 56/100
# 193/193 [==============================] - 0s 1ms/step - loss: -16713.6289 - accuracy: 0.1786 - val_loss: 3296.6941 - val_accuracy: 0.1660
# Epoch 57/100
# 193/193 [==============================] - 0s 1ms/step - loss: -15611.6562 - accuracy: 0.1495 - val_loss: 2978.4417 - val_accuracy: 0.0913
# Epoch 58/100
# 193/193 [==============================] - 0s 1ms/step - loss: -15860.8076 - accuracy: 0.1433 - val_loss: 3102.1484 - val_accuracy: 0.0830
# Epoch 59/100
# 193/193 [==============================] - 0s 1ms/step - loss: -16776.1406 - accuracy: 0.1630 - val_loss: 3228.1838 - val_accuracy: 0.0871
# Epoch 60/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18374.7559 - accuracy: 0.1454 - val_loss: 3268.3298 - val_accuracy: 0.0913
# Epoch 61/100
# 193/193 [==============================] - 0s 1ms/step - loss: -15535.6885 - accuracy: 0.1402 - val_loss: 3282.8730 - val_accuracy: 0.0954
# Epoch 62/100
# 193/193 [==============================] - 0s 1ms/step - loss: -16098.2354 - accuracy: 0.1558 - val_loss: 3287.8071 - val_accuracy: 0.1037
# Epoch 63/100
# 193/193 [==============================] - 0s 1ms/step - loss: -17408.6367 - accuracy: 0.1537 - val_loss: 3001.5098 - val_accuracy: 0.0954
# Epoch 64/100
# 193/193 [==============================] - 0s 1ms/step - loss: -14704.8691 - accuracy: 0.1537 - val_loss: 3303.0581 - val_accuracy: 0.1328
# Epoch 65/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18364.7148 - accuracy: 0.1568 - val_loss: 3610.8777 - val_accuracy: 0.0830
# Epoch 66/100
# 193/193 [==============================] - 0s 1ms/step - loss: -17933.4707 - accuracy: 0.1308 - val_loss: 3242.5784 - val_accuracy: 0.1411
# Epoch 67/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18488.2637 - accuracy: 0.1516 - val_loss: 3579.3628 - val_accuracy: 0.0996
# Epoch 68/100
# 193/193 [==============================] - 0s 1ms/step - loss: -16806.7266 - accuracy: 0.1433 - val_loss: 3420.7249 - val_accuracy: 0.1037
# Epoch 69/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18560.0254 - accuracy: 0.1454 - val_loss: 3189.0103 - val_accuracy: 0.0996
# Epoch 70/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18313.7148 - accuracy: 0.1391 - val_loss: 3639.8569 - val_accuracy: 0.1618
# Epoch 71/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18777.8652 - accuracy: 0.1464 - val_loss: 3680.4866 - val_accuracy: 0.1037
# Epoch 72/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18458.6777 - accuracy: 0.1651 - val_loss: 3253.9534 - val_accuracy: 0.1577
# Epoch 73/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18949.5000 - accuracy: 0.1745 - val_loss: 3517.7961 - val_accuracy: 0.0788
# Epoch 74/100
# 193/193 [==============================] - 0s 1ms/step - loss: -20049.0762 - accuracy: 0.1423 - val_loss: 3320.0784 - val_accuracy: 0.0954
# Epoch 75/100
# 193/193 [==============================] - 0s 1ms/step - loss: -19553.8633 - accuracy: 0.1423 - val_loss: 3460.7100 - val_accuracy: 0.1452
# Epoch 76/100
# 193/193 [==============================] - 0s 1ms/step - loss: -20071.2441 - accuracy: 0.1589 - val_loss: 3224.7705 - val_accuracy: 0.0954
# Epoch 77/100
# 193/193 [==============================] - 0s 1ms/step - loss: -17698.1543 - accuracy: 0.1620 - val_loss: 3387.4348 - val_accuracy: 0.1577
# Epoch 78/100
# 193/193 [==============================] - 0s 1ms/step - loss: -21979.7988 - accuracy: 0.1340 - val_loss: 3195.9233 - val_accuracy: 0.1577
# Epoch 79/100
# 193/193 [==============================] - 0s 1ms/step - loss: -24196.5312 - accuracy: 0.1412 - val_loss: 3686.0586 - val_accuracy: 0.0788
# Epoch 80/100
# 193/193 [==============================] - 0s 1ms/step - loss: -20947.7617 - accuracy: 0.1495 - val_loss: 3258.1443 - val_accuracy: 0.1494
# Epoch 81/100
# 193/193 [==============================] - 0s 1ms/step - loss: -21073.7793 - accuracy: 0.1641 - val_loss: 3945.9258 - val_accuracy: 0.1660
# Epoch 82/100
# 193/193 [==============================] - 0s 1ms/step - loss: -23018.4160 - accuracy: 0.1381 - val_loss: 3359.9817 - val_accuracy: 0.0913
# Epoch 83/100
# 193/193 [==============================] - 0s 1ms/step - loss: -22577.9375 - accuracy: 0.1765 - val_loss: 2828.5417 - val_accuracy: 0.1162
# Epoch 84/100
# 193/193 [==============================] - 0s 1ms/step - loss: -18944.4043 - accuracy: 0.1412 - val_loss: 2820.7490 - val_accuracy: 0.1203
# Epoch 85/100
# 193/193 [==============================] - 0s 1ms/step - loss: -23978.8574 - accuracy: 0.1464 - val_loss: 2869.6116 - val_accuracy: 0.1162
# Epoch 86/100
# 193/193 [==============================] - 0s 1ms/step - loss: -22034.6445 - accuracy: 0.1381 - val_loss: 3046.0493 - val_accuracy: 0.1162
# Epoch 87/100
# 193/193 [==============================] - 0s 1ms/step - loss: -25163.7930 - accuracy: 0.1464 - val_loss: 3317.8613 - val_accuracy: 0.0913
# Epoch 88/100
# 193/193 [==============================] - 0s 1ms/step - loss: -24900.4961 - accuracy: 0.1423 - val_loss: 3025.3599 - val_accuracy: 0.1618
# Epoch 89/100
# 193/193 [==============================] - 0s 1ms/step - loss: -22915.3535 - accuracy: 0.1423 - val_loss: 3643.3899 - val_accuracy: 0.1452
# Epoch 90/100
# 193/193 [==============================] - 0s 1ms/step - loss: -25688.6270 - accuracy: 0.1526 - val_loss: 3589.9070 - val_accuracy: 0.1328
# Epoch 91/100
# 193/193 [==============================] - 0s 1ms/step - loss: -23647.0215 - accuracy: 0.1599 - val_loss: 3433.9492 - val_accuracy: 0.0954
# Epoch 92/100
# 193/193 [==============================] - 0s 1ms/step - loss: -27879.6211 - accuracy: 0.1578 - val_loss: 4009.9631 - val_accuracy: 0.0871
# Epoch 93/100
# 193/193 [==============================] - 0s 1ms/step - loss: -26997.0508 - accuracy: 0.1329 - val_loss: 3094.1738 - val_accuracy: 0.1701
# Epoch 94/100
# 193/193 [==============================] - 0s 1ms/step - loss: -28572.3848 - accuracy: 0.1371 - val_loss: 3021.0750 - val_accuracy: 0.1411
# Epoch 95/100
# 193/193 [==============================] - 0s 1ms/step - loss: -28348.6680 - accuracy: 0.1610 - val_loss: 3741.4272 - val_accuracy: 0.1328
# Epoch 96/100
# 193/193 [==============================] - 0s 1ms/step - loss: -29572.8066 - accuracy: 0.1308 - val_loss: 3460.3145 - val_accuracy: 0.1203
# Epoch 97/100
# 193/193 [==============================] - 0s 1ms/step - loss: -31175.9355 - accuracy: 0.1516 - val_loss: 3535.5107 - val_accuracy: 0.1535
# Epoch 98/100
# 193/193 [==============================] - 0s 1ms/step - loss: -25752.6816 - accuracy: 0.1163 - val_loss: 3995.5522 - val_accuracy: 0.0871
# Epoch 99/100
# 193/193 [==============================] - 0s 1ms/step - loss: -31660.6875 - accuracy: 0.1443 - val_loss: 4321.1328 - val_accuracy: 0.0830
# Epoch 100/100
# 193/193 [==============================] - 0s 1ms/step - loss: -31736.0781 - accuracy: 0.1589 - val_loss: 3948.6292 - val_accuracy: 0.1535

# %%
x_train, x_test, y_train, y_test = train_test_split(X.reshape(X.shape[0],-1), df.iloc[:,1:].values, test_size = 0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (963, 25088)
